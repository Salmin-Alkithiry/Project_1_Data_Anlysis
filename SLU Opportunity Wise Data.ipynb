# %% [markdown]
# <a href="https://colab.research.google.com/github/Salmin-Alkithiry/Project_1_Data_Anlysis/blob/main/SLU%20Opportunity%20Wise%20Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import the required libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %% [markdown]
# # Reading the dataset

# %%
df=pd.read_csv("/content/SLU Opportunity Wise Data.csv")
df.head().T
# Out:
#                                                                          0  \
# Learner SignUp DateTime                                06/14/2023 12:30:35
# Opportunity Id                              00000000-0GN2-A0AY-7XK8-C5FZPP
# Opportunity Name         Career Essentials: Getting Started with Your P...
# Opportunity Category                                                Course
# Opportunity End Date                                   06/29/2024 18:52:39
# First Name                                                           Faria
# Date of Birth                                                   01/12/2001
# Gender                                                              Female
# Country                                                           Pakistan
# Institution Name                                                     Nwihs
# Current/Intended Major                                           Radiology
# ...

# %%
df.tail()
# Out:
#      Learner SignUp DateTime                  Opportunity Id  \
# 8553     03/05/2024 16:39:21  00000000-10GQ-RJHT-3G4S-BKGBY1
# 8554     03/06/2024 15:58:47  00000000-10GQ-RJHT-3G4S-BKGBY1
# 8555     02/29/2024 15:02:31  00000000-10GQ-RJHT-3G4S-BKGBY1
# 8556     12/23/2023 03:53:12  00000000-10GQ-RJHT-3G4S-BKGBY1
# 8557     06/01/2023 13:22:01  00000000-10GQ-RJHT-3G4S-BKGBY1
#
#                 Opportunity Name Opportunity Category Opportunity End Date  \
# 8553  Freelance Mastery workshop                Event  03/08/2024 11:30:00
# 8554  Freelance Mastery workshop                Event  03/08/2024 11:30:00
# 8555  Freelance Mastery workshop                Event  03/08/2024 11:30:00
# 8556  Freelance Mastery workshop                Event  03/08/2024 11:30:00
# 8557  Freelance Mastery workshop                Event  03/08/2024 11:30:00
#
#            First Name Date of Birth  Gender        Country  \
# 8553            Selam    10/14/2006  Female       Ethiopia
# ...

# %% [markdown]
# # Accesing and manipulating Columns names

# %%
df.columns.tolist()
# Out:
# ['Learner SignUp DateTime',
#  'Opportunity Id',
#  'Opportunity Name',
#  'Opportunity Category',
#  'Opportunity End Date',
#  'First Name',
#  'Date of Birth',
#  'Gender',
#  'Country',
#  'Institution Name',
#  'Current/Intended Major',
#  'Entry created at',
#  'Status Description',
#  'Status Code',
#  'Apply Date',
#  'Opportunity Start Date']

# %%
df.columns.tolist()
# Out:
# ['Learner SignUp DateTime',
#  'Opportunity Id',
#  'Opportunity Name',
#  'Opportunity Category',
#  'Opportunity End Date',
#  'Date of Birth',
#  'Gender',
#  'Country',
#  'Institution Name',
#  'Current/Intended Major',
#  'Entry created at',
#  'Status Description',
#  'Status Code',
#  'Apply Date',
#  'Opportunity Start Date']

# %% [markdown]
# # Initial data structure

# %%
df.shape
# Out:
# (8558, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8558 entries, 0 to 8557
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Learner SignUp DateTime  8558 non-null   object
#  1   Opportunity Id           8558 non-null   object
#  2   Opportunity Name         8558 non-null   object
#  3   Opportunity Category     8558 non-null   object
#  4   Opportunity End Date     8558 non-null   object
#  5   Date of Birth            8558 non-null   object
#  6   Gender                   8558 non-null   object
#  7   Country                  8558 non-null   object
#  8   Institution Name         8553 non-null   object
#  9   Current/Intended Major   8553 non-null   object
#  10  Entry created at         8558 non-null   object
#  11  Status Description       8558 non-null   object
#  12  Status Code              8558 non-null   int64
#  13  Apply Date               8558 non-null   object
# ...

# %% [markdown]
# # Coverting all date columns to date time format
